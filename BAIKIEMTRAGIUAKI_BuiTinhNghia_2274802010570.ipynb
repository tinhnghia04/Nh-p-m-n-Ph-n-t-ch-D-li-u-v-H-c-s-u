# %% [markdown]
# # KIỂM TRA GIỮA KÌ

# %% [markdown]
# ## Câu 1: Tạo Dataframe như dữ liệu đã cho trên.

# %%
import pandas as pd


# 1. Tạo DataFrame từ dữ liệu
data = {
    'Name': ["Mr. Harris", "Mrs. Bradley", "Miss. Laina", "Mrs. Heath", "Mr. William", "Mr. James",
             "Mr. Timothy", "Mrs. Oscar", "Mrs. Nicholas", "Miss. Marguerite", "Mr. William",
             "Miss. Hulda", "Mr. Lawrence", "Mr. Wilam"],
    'Height': [1.80, 1.61, 1.78, 1.74, 1.55, 1.9, 1.61, 1.40, 1.92, 1.77, 1.55, 1.85, 1.64, 1.77],
    'Weight': [90, 87, 64, 70, 100, 106, 82, 55, 77, 60, 100, 109, 80, 66],
    'AGE': [32, 45, 22, 52, 48, 21, 28, 69, 58, 21, 48, 33, 25, 70]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                 Name  Height  Weight  AGE
# 0         Mr. Harris    1.80      90   32
# 1       Mrs. Bradley    1.61      87   45
# 2        Miss. Laina    1.78      64   22
# 3         Mrs. Heath    1.74      70   52
# 4        Mr. William    1.55     100   48
# 5          Mr. James    1.90     106   21
# 6        Mr. Timothy    1.61      82   28
# 7         Mrs. Oscar    1.40      55   69
# 8      Mrs. Nicholas    1.92      77   58
# 9   Miss. Marguerite    1.77      60   21
# 10       Mr. William    1.55     100   48
# 11       Miss. Hulda    1.85     109   33
# 12      Mr. Lawrence    1.64      80   25
# 13         Mr. Wilam    1.77      66   70

# %% [markdown]
# ## Câu 2: Hiển thị thông tin Dataframe vừa tạo.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    14 non-null     object
#  1   Height  14 non-null     float64
#  2   Weight  14 non-null     int64
#  3   AGE     14 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 580.0+ bytes
# None

# %% [markdown]
# ## Câu 3: Tính giá trị trung bình của cột AGE.

# %%
mean_age = df['AGE'].mean()
print("Giá trị trung bình của AGE:", mean_age)
# Out:
# Giá trị trung bình của AGE: 40.857142857142854

# %% [markdown]
# ## Câu 4: Nhóm dữ liệu cột Height và trung bình cột Weight.

# %%
height_group = df.groupby('Height')['Weight'].mean()
print(height_group)
# Out:
# Height
# 1.40     55.0
# 1.55    100.0
# 1.61     84.5
# 1.64     80.0
# 1.74     70.0
# 1.77     63.0
# 1.78     64.0
# 1.80     90.0
# 1.85    109.0
# 1.90    106.0
# 1.92     77.0
# Name: Weight, dtype: float64

# %% [markdown]
# ## Câu 5: Sắp xếp Dataframe theo cột Weight tăng dần.

# %%
df_sorted = df.sort_values(by='Weight', ascending=True)
print(df_sorted)
# Out:
#                 Name  Height  Weight  AGE
# 7         Mrs. Oscar    1.40      55   69
# 9   Miss. Marguerite    1.77      60   21
# 2        Miss. Laina    1.78      64   22
# 13         Mr. Wilam    1.77      66   70
# 3         Mrs. Heath    1.74      70   52
# 8      Mrs. Nicholas    1.92      77   58
# 12      Mr. Lawrence    1.64      80   25
# 6        Mr. Timothy    1.61      82   28
# 1       Mrs. Bradley    1.61      87   45
# 0         Mr. Harris    1.80      90   32
# 10       Mr. William    1.55     100   48
# 4        Mr. William    1.55     100   48
# 5          Mr. James    1.90     106   21
# 11       Miss. Hulda    1.85     109   33

# %% [markdown]
# ## Câu 6: Vẽ biểu đồ cột cho AGE.

# %%
plt.figure(figsize=(8,5))
plt.bar(df['Name'], df['AGE'], color='blue')
plt.xticks(rotation=90)
plt.xlabel("Name")
plt.ylabel("AGE")
plt.title("Biểu đồ cột của AGE")
plt.show()

# %% [markdown]
# ## Câu 7: Vẽ biểu đồ phân tán cho AGE và Height.

# %%
plt.scatter(df['AGE'], df['Height'], color='red')
plt.xlabel("AGE")
plt.ylabel("Height")
plt.title("Biểu đồ phân tán AGE vs Height")
plt.show()

# %% [markdown]
# ## Câu 8: Vẽ biểu đồ đường cho cột Weight.

# %%
plt.plot(df['Weight'], marker='o', linestyle='-')
plt.xlabel("Index")
plt.ylabel("Weight")
plt.title("Biểu đồ đường của Weight")
plt.show()

# %% [markdown]
# ## Câu 9: Vẽ biểu đồ tròn cho cột Height.

# %%
plt.pie(df['Height'], labels=df['Name'], autopct='%1.1f%%')
plt.title("Biểu đồ tròn của Height")
plt.show()

# %% [markdown]
# ## Câu 10: Vẽ biểu đồ phân tán cho cột Weight,AGE.

# %%
plt.scatter(df['Weight'], df['AGE'], color='green')
plt.xlabel("Weight")
plt.ylabel("AGE")
plt.title("Biểu đồ phân tán Weight vs AGE")
plt.show()

# %% [markdown]
# ## Câu 11: Kiểm tra có giá trị NaN nào trong DataFrame không.

# %%
print(df.isnull().sum())
# Out:
# Name      0
# Height    0
# Weight    0
# AGE       0
# dtype: int64

# %% [markdown]
# ## Câu 12: Tìm các giá trị trùng lặp trong DataFrame dựa trên cột 'Name' và loại bỏ các hàng trùng lặp, giữ lại hàng đầu tiên.

# %%
df = df.drop_duplicates(subset=['Name'], keep='first')
print(df)
# Out:
#                 Name  Height  Weight  AGE
# 0         Mr. Harris    1.80      90   32
# 1       Mrs. Bradley    1.61      87   45
# 2        Miss. Laina    1.78      64   22
# 3         Mrs. Heath    1.74      70   52
# 4        Mr. William    1.55     100   48
# 5          Mr. James    1.90     106   21
# 6        Mr. Timothy    1.61      82   28
# 7         Mrs. Oscar    1.40      55   69
# 8      Mrs. Nicholas    1.92      77   58
# 9   Miss. Marguerite    1.77      60   21
# 11       Miss. Hulda    1.85     109   33
# 12      Mr. Lawrence    1.64      80   25
# 13         Mr. Wilam    1.77      66   70

# %% [markdown]
# ## Câu 13: Thay thế các giá trị của cột Age lớn hơn 40 bằng giá trị trung bình của cột đó.

# %%
df.loc[df['AGE'] > 40, 'AGE'] = mean_age
print(df)
# Out:
#                 Name  Height  Weight        AGE
# 0         Mr. Harris    1.80      90  32.000000
# 1       Mrs. Bradley    1.61      87  40.857143
# 2        Miss. Laina    1.78      64  22.000000
# 3         Mrs. Heath    1.74      70  40.857143
# 4        Mr. William    1.55     100  40.857143
# 5          Mr. James    1.90     106  21.000000
# 6        Mr. Timothy    1.61      82  28.000000
# 7         Mrs. Oscar    1.40      55  40.857143
# 8      Mrs. Nicholas    1.92      77  40.857143
# 9   Miss. Marguerite    1.77      60  21.000000
# 11       Miss. Hulda    1.85     109  33.000000
# 12      Mr. Lawrence    1.64      80  25.000000
# 13         Mr. Wilam    1.77      66  40.857143
# ...

# %% [markdown]
# ## Câu 14: Biết công thức tính chỉ số BMI như sau:BMI = Weight(kg)/Height2 (m2)
# ## Tạo một cột mới trong Dataframe với tên cs_BMI, tính chỉ số BIM mỗi người

# %%
df['cs_BMI'] = df['Weight'] / (df['Height'] ** 2)
print(df)
# Out:
#                 Name  Height  Weight        AGE     cs_BMI
# 0         Mr. Harris    1.80      90  32.000000  27.777778
# 1       Mrs. Bradley    1.61      87  40.857143  33.563520
# 2        Miss. Laina    1.78      64  22.000000  20.199470
# 3         Mrs. Heath    1.74      70  40.857143  23.120624
# 4        Mr. William    1.55     100  40.857143  41.623309
# 5          Mr. James    1.90     106  21.000000  29.362881
# 6        Mr. Timothy    1.61      82  28.000000  31.634582
# 7         Mrs. Oscar    1.40      55  40.857143  28.061224
# 8      Mrs. Nicholas    1.92      77  40.857143  20.887587
# 9   Miss. Marguerite    1.77      60  21.000000  19.151585
# 11       Miss. Hulda    1.85     109  33.000000  31.848064
# 12      Mr. Lawrence    1.64      80  25.000000  29.744200
# 13         Mr. Wilam    1.77      66  40.857143  21.066743

# %% [markdown]
# ## Câu 15: heo thang đo kết quả tính BMI của châu Á: Chỉ số BMI dưới 18,5 là thiếu cân, 18.5-22,9 là bình thường, 23-24,9 là thừa cân, từ 25 trở lên là béo phì.
# ## Tạo cột với tên <Phan_Loai> với các mức ‘0’,’1’,’2’,’3’ tương ứng với mức chỉ số BMI trên.

# %%
def classify_bmi(bmi):
    if bmi < 18.5:
        return 0  # Thiếu cân
    elif 18.5 <= bmi < 23:
        return 1  # Bình thường
    elif 23 <= bmi < 25:
        return 2  # Thừa cân
    else:
        return 3  # Béo phì
df["Phân loại"] = df["cs_BMI"].apply(classify_bmi)
print(df)
# Out:
#                 Name  Height  Weight        AGE     cs_BMI  Phân loại
# 0         Mr. Harris    1.80      90  32.000000  27.777778          3
# 1       Mrs. Bradley    1.61      87  40.857143  33.563520          3
# 2        Miss. Laina    1.78      64  22.000000  20.199470          1
# 3         Mrs. Heath    1.74      70  40.857143  23.120624          2
# 4        Mr. William    1.55     100  40.857143  41.623309          3
# 5          Mr. James    1.90     106  21.000000  29.362881          3
# 6        Mr. Timothy    1.61      82  28.000000  31.634582          3
# 7         Mrs. Oscar    1.40      55  40.857143  28.061224          3
# 8      Mrs. Nicholas    1.92      77  40.857143  20.887587          1
# 9   Miss. Marguerite    1.77      60  21.000000  19.151585          1
# 11       Miss. Hulda    1.85     109  33.000000  31.848064          3
# 12      Mr. Lawrence    1.64      80  25.000000  29.744200          3
# ...

# %% [markdown]
# ## Câu 16: Chuẩn hóa giá trị của cột cs_BMI chuẩn hóa giá trị trong đoạn từ 0 tới 1.

# %%
df["cs_BMI_norm"] = (df["cs_BMI"] - df["cs_BMI"].min()) / (df["cs_BMI"].max() - df["cs_BMI"].min())

print("DataFrame sau khi chuẩn hóa cs_BMI:")
print(df)
# Out:
# DataFrame sau khi chuẩn hóa cs_BMI:
#                 Name  Height  Weight        AGE     cs_BMI  Phân loại  \
# 0         Mr. Harris    1.80      90  32.000000  27.777778          3
# 1       Mrs. Bradley    1.61      87  40.857143  33.563520          3
# 2        Miss. Laina    1.78      64  22.000000  20.199470          1
# 3         Mrs. Heath    1.74      70  40.857143  23.120624          2
# 4        Mr. William    1.55     100  40.857143  41.623309          3
# 5          Mr. James    1.90     106  21.000000  29.362881          3
# 6        Mr. Timothy    1.61      82  28.000000  31.634582          3
# 7         Mrs. Oscar    1.40      55  40.857143  28.061224          3
# 8      Mrs. Nicholas    1.92      77  40.857143  20.887587          1
# 9   Miss. Marguerite    1.77      60  21.000000  19.151585          1
# 11       Miss. Hulda    1.85     109  33.000000  31.848064          3
# 12      Mr. Lawrence    1.64      80  25.000000  29.744200          3
# ...

# %% [markdown]
# ## Câu 17: Cho biết:
# ## + ‘Mr‘tương ứng với ‘male’,
# ## + ’Mrs’ và ‘Miss’ tương ứng với ‘female’.
# ## Tạo cột với tên <GT>, Sau khi thực hiện, xóa các từ Mr, Mrs, Miss nếu trong cột <Name> còn các từ đó.

# %%
data = {
    "Name": ["Mr. Harris", "Mrs. Bradley", "Miss. Laina", "Mrs. Heath", "Mr. William",
             "Mr. James", "Mr. Timothy", "Mrs. Oscar", "Mrs. Nicholas", "Miss. Marguerite",
             "Mr. William", "Miss. Hulda", "Mr. Lawrence", "Mr. Wilam"],
    "Height": [1.80, 1.61, 1.78, 1.74, 1.55, 1.9, 1.61, 1.40, 1.92, 1.77, 1.55, 1.85, 1.64, 1.77],
    "Weight": [90, 87, 64, 70, 100, 106, 82, 55, 77, 60, 100, 109, 80, 66],
    "Age": [32, 45, 22, 52, 48, 21, 28, 69, 58, 21, 48, 33, 25, 70]
}

df = pd.DataFrame(data)
def get_gender(name):
    if name.startswith("Mr."):
        return "Male"
    elif name.startswith("Mrs.") or name.startswith("Miss."):
        return "Female"
    return "Unknown"

df["GT"] = df["Name"].apply(get_gender)

df["Name"] = df["Name"].str.replace(r'^(Mr\.|Mrs\.|Miss\.)\s+', '', regex=True)
print(df)
# Out:
#           Name  Height  Weight  Age      GT
# 0       Harris    1.80      90   32    Male
# 1      Bradley    1.61      87   45  Female
# 2        Laina    1.78      64   22  Female
# 3        Heath    1.74      70   52  Female
# 4      William    1.55     100   48    Male
# 5        James    1.90     106   21    Male
# 6      Timothy    1.61      82   28    Male
# 7        Oscar    1.40      55   69  Female
# 8     Nicholas    1.92      77   58  Female
# 9   Marguerite    1.77      60   21  Female
# 10     William    1.55     100   48    Male
# 11       Hulda    1.85     109   33  Female
# 12    Lawrence    1.64      80   25    Male
# 13       Wilam    1.77      66   70    Male

# %% [markdown]
# ## Câu 18: Vẽ biểu đồ tròn cho GT.

# %%
df['GT'].value_counts().plot.pie(autopct='%1.1f%%', colors=['blue', 'pink'])
plt.title("Tỉ lệ giới tính trong DataFrame")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Câu 19: Trực quan hóa dữ liệu người nữ trên Phan_Loai.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Name": ["Mr. Harris", "Mrs. Bradley", "Miss. Laina", "Mrs. Heath", "Mr. William",
             "Mr. James", "Mr. Timothy", "Mrs. Oscar", "Mrs. Nicholas", "Miss. Marguerite",
             "Mr. William", "Miss. Hulda", "Mr. Lawrence", "Mr. Wilam"],
    "Height": [1.80, 1.61, 1.78, 1.74, 1.55, 1.9, 1.61, 1.40, 1.92, 1.77, 1.55, 1.85, 1.64, 1.77],
    "Weight": [90, 87, 64, 70, 100, 106, 82, 55, 77, 60, 100, 109, 80, 66],
    "Age": [32, 45, 22, 52, 48, 21, 28, 69, 58, 21, 48, 33, 25, 70]
}

df = pd.DataFrame(data)

def get_gender(name):
    if name.startswith("Mr."):
        return "Male"
    elif name.startswith("Mrs.") or name.startswith("Miss."):
        return "Female"
    return "Unknown"

df["GT"] = df["Name"].apply(get_gender)

df["Name"] = df["Name"].str.replace(r'^(Mr\.|Mrs\.|Miss\.)\s+', '', regex=True)

print(df)

female_df = df[df["GT"] == "Female"]
plt.figure(figsize=(10, 5))
plt.bar(female_df["Name"], female_df["Height"], color='blue', label='Chiều cao')
plt.bar(female_df["Name"], female_df["Weight"], color='red', alpha=0.6, label='Cân nặng')

plt.xlabel("Tên")
plt.ylabel("Giá trị")
plt.title("Biểu đồ chiều cao và cân nặng của người nữ")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
#           Name  Height  Weight  Age      GT
# 0       Harris    1.80      90   32    Male
# 1      Bradley    1.61      87   45  Female
# 2        Laina    1.78      64   22  Female
# 3        Heath    1.74      70   52  Female
# 4      William    1.55     100   48    Male
# 5        James    1.90     106   21    Male
# 6      Timothy    1.61      82   28    Male
# 7        Oscar    1.40      55   69  Female
# 8     Nicholas    1.92      77   58  Female
# 9   Marguerite    1.77      60   21  Female
# 10     William    1.55     100   48    Male
# 11       Hulda    1.85     109   33  Female
# 12    Lawrence    1.64      80   25    Male
# 13       Wilam    1.77      66   70    Male

# %% [markdown]
# ## Câu 20: Lưu DataFrame với tên <BKT_MSSV_Hoten.csv

# %%
df.to_csv("BKT_2274802010570_BuiTinhNghia.csv", index=False)
print("dataframe đã được lưu thành công !")
# Out:
# dataframe đã được lưu thành công !
